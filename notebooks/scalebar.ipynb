# %%
# %matplotlib inline

# %%
#for scale function
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib

#for tests
import cartopy.crs as ccrs  # projections
from cartopy.mpl.geoaxes import GeoAxes

from impactutils.mapping.scalebar import draw_scale

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -65, 15, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 15, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(4,8))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 15, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 15, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -50, 25, 35])
draw_scale(ax)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='lr')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ur')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ul')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ll',padx=0.2)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ur',padx=0.05,pady=0.2)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ur',padx=0.05,pady=0.2,font_size=18)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,units='km')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.PlateCarree())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,units='km')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ll',font_size=12,padx=0.05)

# %%
fig = plt.figure(figsize=(4,4))
proj = ccrs.AlbersEqualArea(central_latitude=30,
                            central_longitude=-82.5,
                            standard_parallels=(30.0))
ax = fig.add_axes([0,0,1,1],projection=proj,)
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ll')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ll',font_size=12,padx=0.05,units='kmi')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,1,1],projection=ccrs.Mercator())
ax.coastlines()
ax.set_extent([-90, -75, 25, 35])
draw_scale(ax,pos='ll',font_size=12,padx=0.05,units='us-mi')
